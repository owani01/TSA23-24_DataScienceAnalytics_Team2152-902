# %%
import pandas as pd
import matplotlib.pyplot as plot

df_Alaska = pd.read_excel("/workspaces/codespaces-jupyter/data_analysis/Disbursements by State Dataset.xlsx", sheet_name="Alaska")
df_Alabama = pd.read_excel("/workspaces/codespaces-jupyter/data_analysis/Disbursements by State Dataset.xlsx", sheet_name="Alabama")
df_Arkansas = pd.read_excel("/workspaces/codespaces-jupyter/data_analysis/Disbursements by State Dataset.xlsx", sheet_name="Arkansas")
df_Arizona = pd.read_excel("/workspaces/codespaces-jupyter/data_analysis/Disbursements by State Dataset.xlsx", sheet_name="Arizona")
df_California = pd.read_excel("/workspaces/codespaces-jupyter/data_analysis/Disbursements by State Dataset.xlsx", sheet_name="California")
df_Colorado = pd.read_excel("/workspaces/codespaces-jupyter/data_analysis/Disbursements by State Dataset.xlsx", sheet_name="Colorado")
df_Connecticut = pd.read_excel("/workspaces/codespaces-jupyter/data_analysis/Disbursements by State Dataset.xlsx", sheet_name="Connecticut")
df_DC = pd.read_excel("/workspaces/codespaces-jupyter/data_analysis/Disbursements by State Dataset.xlsx", sheet_name="District of Columbia")
df_Delaware = pd.read_excel("/workspaces/codespaces-jupyter/data_analysis/Disbursements by State Dataset.xlsx", sheet_name="Delaware")
df_Florida = pd.read_excel("/workspaces/codespaces-jupyter/data_analysis/Disbursements by State Dataset.xlsx", sheet_name="Florida")
df_Georgia = pd.read_excel("/workspaces/codespaces-jupyter/data_analysis/Disbursements by State Dataset.xlsx", sheet_name="Georgia")
df_Guam = pd.read_excel("/workspaces/codespaces-jupyter/data_analysis/Disbursements by State Dataset.xlsx", sheet_name="Guam")
df_Hawaii = pd.read_excel("/workspaces/codespaces-jupyter/data_analysis/Disbursements by State Dataset.xlsx", sheet_name="Hawaii")
df_Iowa = pd.read_excel("/workspaces/codespaces-jupyter/data_analysis/Disbursements by State Dataset.xlsx", sheet_name="Iowa")
df_Idaho = pd.read_excel("/workspaces/codespaces-jupyter/data_analysis/Disbursements by State Dataset.xlsx", sheet_name="Idaho")
df_Illinois = pd.read_excel("/workspaces/codespaces-jupyter/data_analysis/Disbursements by State Dataset.xlsx", sheet_name="Illinois")
df_Indiana = pd.read_excel("/workspaces/codespaces-jupyter/data_analysis/Disbursements by State Dataset.xlsx", sheet_name="Indiana")
df_Kansas = pd.read_excel("/workspaces/codespaces-jupyter/data_analysis/Disbursements by State Dataset.xlsx", sheet_name="Kansas")
df_Kentucky = pd.read_excel("/workspaces/codespaces-jupyter/data_analysis/Disbursements by State Dataset.xlsx", sheet_name="Kentucky")
df_Louisiana = pd.read_excel("/workspaces/codespaces-jupyter/data_analysis/Disbursements by State Dataset.xlsx", sheet_name="Louisiana")
df_Massachusetts = pd.read_excel("/workspaces/codespaces-jupyter/data_analysis/Disbursements by State Dataset.xlsx", sheet_name="Massachusetts")
df_Maryland = pd.read_excel("/workspaces/codespaces-jupyter/data_analysis/Disbursements by State Dataset.xlsx", sheet_name="Maryland")
df_Maine = pd.read_excel("/workspaces/codespaces-jupyter/data_analysis/Disbursements by State Dataset.xlsx", sheet_name="Maine")
df_Michigan = pd.read_excel("/workspaces/codespaces-jupyter/data_analysis/Disbursements by State Dataset.xlsx", sheet_name="Michigan")
df_Minnesota = pd.read_excel("/workspaces/codespaces-jupyter/data_analysis/Disbursements by State Dataset.xlsx", sheet_name="Minnesota")
df_Missouri = pd.read_excel("/workspaces/codespaces-jupyter/data_analysis/Disbursements by State Dataset.xlsx", sheet_name="Missouri")
df_Mississippi = pd.read_excel("/workspaces/codespaces-jupyter/data_analysis/Disbursements by State Dataset.xlsx", sheet_name="Mississippi")
df_Montana = pd.read_excel("/workspaces/codespaces-jupyter/data_analysis/Disbursements by State Dataset.xlsx", sheet_name="Montana")
df_NorthCarolina = pd.read_excel("/workspaces/codespaces-jupyter/data_analysis/Disbursements by State Dataset.xlsx", sheet_name="North Carolina")
df_NorthDakota = pd.read_excel("/workspaces/codespaces-jupyter/data_analysis/Disbursements by State Dataset.xlsx", sheet_name="North Dakota")
df_Nebraska = pd.read_excel("/workspaces/codespaces-jupyter/data_analysis/Disbursements by State Dataset.xlsx", sheet_name="Nebraska")
df_NewHampshire = pd.read_excel("/workspaces/codespaces-jupyter/data_analysis/Disbursements by State Dataset.xlsx", sheet_name="New Hampshire")
df_NewJersey = pd.read_excel("/workspaces/codespaces-jupyter/data_analysis/Disbursements by State Dataset.xlsx", sheet_name="New Jersey")
df_NewMexico = pd.read_excel("/workspaces/codespaces-jupyter/data_analysis/Disbursements by State Dataset.xlsx", sheet_name="New Mexico")
df_Nevada = pd.read_excel("/workspaces/codespaces-jupyter/data_analysis/Disbursements by State Dataset.xlsx", sheet_name="Nevada")
df_NewYork = pd.read_excel("/workspaces/codespaces-jupyter/data_analysis/Disbursements by State Dataset.xlsx", sheet_name="New York")
df_Ohio = pd.read_excel("/workspaces/codespaces-jupyter/data_analysis/Disbursements by State Dataset.xlsx", sheet_name="Ohio")
df_Oklahoma = pd.read_excel("/workspaces/codespaces-jupyter/data_analysis/Disbursements by State Dataset.xlsx", sheet_name="Oklahoma")
df_Oregon = pd.read_excel("/workspaces/codespaces-jupyter/data_analysis/Disbursements by State Dataset.xlsx", sheet_name="Oregon")
df_Pennsylvania = pd.read_excel("/workspaces/codespaces-jupyter/data_analysis/Disbursements by State Dataset.xlsx", sheet_name="Pennsylvania")
df_PuertoRico = pd.read_excel("/workspaces/codespaces-jupyter/data_analysis/Disbursements by State Dataset.xlsx", sheet_name="Puerto Rico")
df_RhodeIsland = pd.read_excel("/workspaces/codespaces-jupyter/data_analysis/Disbursements by State Dataset.xlsx", sheet_name="Rhode Island")
df_SouthCarolina = pd.read_excel("/workspaces/codespaces-jupyter/data_analysis/Disbursements by State Dataset.xlsx", sheet_name="South Carolina")
df_SouthDakota = pd.read_excel("/workspaces/codespaces-jupyter/data_analysis/Disbursements by State Dataset.xlsx", sheet_name="South Dakota")
df_Tennessee = pd.read_excel("/workspaces/codespaces-jupyter/data_analysis/Disbursements by State Dataset.xlsx", sheet_name="Tennessee")
df_Texas = pd.read_excel("/workspaces/codespaces-jupyter/data_analysis/Disbursements by State Dataset.xlsx", sheet_name="Texas")
df_Utah = pd.read_excel("/workspaces/codespaces-jupyter/data_analysis/Disbursements by State Dataset.xlsx", sheet_name="Utah")
df_Virginia = pd.read_excel("/workspaces/codespaces-jupyter/data_analysis/Disbursements by State Dataset.xlsx", sheet_name="Virginia")
df_VirginIslands = pd.read_excel("/workspaces/codespaces-jupyter/data_analysis/Disbursements by State Dataset.xlsx", sheet_name="Virgin Islands")
df_Vermont = pd.read_excel("/workspaces/codespaces-jupyter/data_analysis/Disbursements by State Dataset.xlsx", sheet_name="Vermont")
df_Washington = pd.read_excel("/workspaces/codespaces-jupyter/data_analysis/Disbursements by State Dataset.xlsx", sheet_name="Washington")
df_Wisconsin = pd.read_excel("/workspaces/codespaces-jupyter/data_analysis/Disbursements by State Dataset.xlsx", sheet_name="Wisconsin")
df_WestVirginia = pd.read_excel("/workspaces/codespaces-jupyter/data_analysis/Disbursements by State Dataset.xlsx", sheet_name="West Virginia")
df_Wyoming = pd.read_excel("/workspaces/codespaces-jupyter/data_analysis/Disbursements by State Dataset.xlsx", sheet_name="Wyoming")
